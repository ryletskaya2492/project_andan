# %%
import pandas as pd
df=pd.read_csv("очищенные_данные_дота1.csv",encoding='utf-8', sep=';', skipinitialspace=True)
df = df.dropna(axis=1, how='all')
df.head()
# Out:
#                Отметка времени  Id Пол  Возраст  Максимальный рейтинг в Доте  \
# 0  2021/11/08 1:10:08 PM GMT+3   2   М       21                          980
# 1  2021/11/08 1:11:03 PM GMT+3   4   М       19                         2370
# 2  2021/11/08 1:11:32 PM GMT+3   5   М       15                         2700
# 3  2021/11/08 1:11:36 PM GMT+3   6   М       17                         4360
# 4  2021/11/08 1:12:00 PM GMT+3   7   М       22                         3000
#
#    Рейтинг в доте на данный момент  \
# 0                              960
# 1                             2130
# 2                             2400
# 3                             4320
# 4                             2100
#
#    Количество часов в игре (хотя бы примерное)  \
# 0                                         2808
# 1                                         4500
# 2                                          700
# 3                                         2600
# 4                                         3700
#
#    Какое количество игр в среднем ты играешь в неделю?  \
# 0                                                  8
# 1                                                 25
# 2                                                 25
# 3                                                 25
# 4                                                  8
#
#    У меня ухудшается настроение, если я долго не играю в Доту 2  \
# 0                                                  1
# 1                                                  3
# 2                                                  1
# 3                                                  4
# 4                                                  1
#
#    Почти все свое свободное время я трачу на Доту 2  ...  \
# 0                                                 2  ...
# 1                                                 4  ...
# 2                                                 3  ...
# 3                                                 4  ...
# 4                                                 2  ...
#
#    Мой возможный птс намного больше, чем мой актуальный  Отстутсвие прогресса  \
# 0                                                  5                        1
# 1                                                  3                        3
# 2                                                  5                        2
# 3                                                  3                        2
# 4                                                  4                        4
#
#    У меня часто пропадает желание играть, когда мои тиммейты играют плохо  \
# 0                                                  3
# 1                                                  5
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#    MMR - это всего лишь цифра, она не показывает реальный скилл игрока  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  2
#
#    Количество времени в игре  Эмоциональная зависимость  \
# 0                          5                          2
# 1                         10                          8
# 2                          8                          2
# 3                         12                          9
# 4                          7                          5
#
#    Негативные последствия  Нацеленность на результат  \
# 0                       4                         11
# 1                       8                         19
# 2                       3                         16
# 3                       8                         20
# 4                       8                         16
#
#    Отсутствие стрессоустойчивости  Макс-реальный
# 0                               8             20
# 1                               7            240
# 2                               7            300
# 3                               7             40
# 4                               6            900
#
# [5 rows x 36 columns]

# %%
df['Отсутствие стрессоустойчивости'] = 15 - df['Отсутствие стрессоустойчивости']
df.to_csv("очищенные_данные_дота1.csv", index=False, sep=';', encoding='utf-8')
df.head()
# Out:
#                Отметка времени  Id Пол  Возраст  Максимальный рейтинг в Доте  \
# 0  2021/11/08 1:10:08 PM GMT+3   2   М       21                          980
# 1  2021/11/08 1:11:03 PM GMT+3   4   М       19                         2370
# 2  2021/11/08 1:11:32 PM GMT+3   5   М       15                         2700
# 3  2021/11/08 1:11:36 PM GMT+3   6   М       17                         4360
# 4  2021/11/08 1:12:00 PM GMT+3   7   М       22                         3000
#
#    Рейтинг в доте на данный момент  \
# 0                              960
# 1                             2130
# 2                             2400
# 3                             4320
# 4                             2100
#
#    Количество часов в игре (хотя бы примерное)  \
# 0                                         2808
# 1                                         4500
# 2                                          700
# 3                                         2600
# 4                                         3700
#
#    Какое количество игр в среднем ты играешь в неделю?  \
# 0                                                  8
# 1                                                 25
# 2                                                 25
# 3                                                 25
# 4                                                  8
#
#    У меня ухудшается настроение, если я долго не играю в Доту 2  \
# 0                                                  1
# 1                                                  3
# 2                                                  1
# 3                                                  4
# 4                                                  1
#
#    Почти все свое свободное время я трачу на Доту 2  ...  \
# 0                                                 2  ...
# 1                                                 4  ...
# 2                                                 3  ...
# 3                                                 4  ...
# 4                                                 2  ...
#
#    Мой возможный птс намного больше, чем мой актуальный  Отстутсвие прогресса  \
# 0                                                  5                        1
# 1                                                  3                        3
# 2                                                  5                        2
# 3                                                  3                        2
# 4                                                  4                        4
#
#    У меня часто пропадает желание играть, когда мои тиммейты играют плохо  \
# 0                                                  3
# 1                                                  5
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#    MMR - это всего лишь цифра, она не показывает реальный скилл игрока  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  2
#
#    Количество времени в игре  Эмоциональная зависимость  \
# 0                          5                          2
# 1                         10                          8
# 2                          8                          2
# 3                         12                          9
# 4                          7                          5
#
#    Негативные последствия  Нацеленность на результат  \
# 0                       4                         11
# 1                       8                         19
# 2                       3                         16
# 3                       8                         20
# 4                       8                         16
#
#    Отсутствие стрессоустойчивости  Макс-реальный
# 0                               7             20
# 1                               8            240
# 2                               8            300
# 3                               8             40
# 4                               9            900
#
# [5 rows x 36 columns]

# %%
df = df.rename(columns={"Нацеленность на результат": "Мотивация"})
df = df.rename(columns={"Отсутствие стрессоустойчивости": "Стрессоустойчивость"})
df.head()
# Out:
#                Отметка времени  Id Пол  Возраст  Максимальный рейтинг в Доте  \
# 0  2021/11/08 1:10:08 PM GMT+3   2   М       21                          980
# 1  2021/11/08 1:11:03 PM GMT+3   4   М       19                         2370
# 2  2021/11/08 1:11:32 PM GMT+3   5   М       15                         2700
# 3  2021/11/08 1:11:36 PM GMT+3   6   М       17                         4360
# 4  2021/11/08 1:12:00 PM GMT+3   7   М       22                         3000
#
#    Рейтинг в доте на данный момент  \
# 0                              960
# 1                             2130
# 2                             2400
# 3                             4320
# 4                             2100
#
#    Количество часов в игре (хотя бы примерное)  \
# 0                                         2808
# 1                                         4500
# 2                                          700
# 3                                         2600
# 4                                         3700
#
#    Какое количество игр в среднем ты играешь в неделю?  \
# 0                                                  8
# 1                                                 25
# 2                                                 25
# 3                                                 25
# 4                                                  8
#
#    У меня ухудшается настроение, если я долго не играю в Доту 2  \
# 0                                                  1
# 1                                                  3
# 2                                                  1
# 3                                                  4
# 4                                                  1
#
#    Почти все свое свободное время я трачу на Доту 2  ...  \
# 0                                                 2  ...
# 1                                                 4  ...
# 2                                                 3  ...
# 3                                                 4  ...
# 4                                                 2  ...
#
#    Мой возможный птс намного больше, чем мой актуальный  Отстутсвие прогресса  \
# 0                                                  5                        1
# 1                                                  3                        3
# 2                                                  5                        2
# 3                                                  3                        2
# 4                                                  4                        4
#
#    У меня часто пропадает желание играть, когда мои тиммейты играют плохо  \
# 0                                                  3
# 1                                                  5
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#    MMR - это всего лишь цифра, она не показывает реальный скилл игрока  \
# 0                                                  5
# 1                                                  5
# 2                                                  3
# 3                                                  1
# 4                                                  2
#
#    Количество времени в игре  Эмоциональная зависимость  \
# 0                          5                          2
# 1                         10                          8
# 2                          8                          2
# 3                         12                          9
# 4                          7                          5
#
#    Негативные последствия  Мотивация  Стрессоустойчивость  Макс-реальный
# 0                       4         11                    7             20
# 1                       8         19                    8            240
# 2                       3         16                    8            300
# 3                       8         20                    8             40
# 4                       8         16                    9            900
#
# [5 rows x 36 columns]

# %%
from scipy.stats import kstest, norm
from scipy.stats import anderson
df_s = df[['Рейтинг в доте на данный момент','Мотивация','Стрессоустойчивость']]
mean = df_s.mean()
std = df_s.std()
desc = df_s.describe().round(3)
desc.loc['mode'] = df_s.mode().iloc[0]
desc.loc['skewness'] = df_s.skew().round(3)
desc.loc['kurtosis'] = df_s.kurtosis().round(3)
desc.loc['ks_stat'] = df_s.apply(lambda x: kstest(x, norm.cdf, args=(mean[x.name], std[x.name])).statistic).round(3)
desc.loc['ks_p'] = df_s.apply(lambda x: kstest(x, norm.cdf, args=(mean[x.name], std[x.name])).pvalue).round(3)
desc.loc['anderson_stat'] = df_s.apply(lambda x: round(anderson(x).statistic, 3))
desc
# Out:
#                Рейтинг в доте на данный момент  Мотивация  Стрессоустойчивость
# count                                 7448.000   7448.000             7448.000
# mean                                  2464.097     15.018                8.482
# std                                  34774.622      3.710                2.748
# min                                      0.000      4.000                0.000
# 25%                                    870.000     13.000                7.000
# 50%                                   1810.000     16.000                9.000
# 75%                                   3000.000     18.000               11.000
# max                                3000000.000     20.000               12.000
# mode                                  2000.000     18.000                9.000
# skewness                                86.029     -0.645               -0.912
# kurtosis                              7416.530     -0.242                0.461
# ks_stat                                  0.472      0.118                0.144
# ks_p                                     0.000      0.000                0.000
# anderson_stat                         2601.405    110.043              163.431

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
sm.qqplot(df['Мотивация'], line='45')
plt.title("Q-Q Plot Мотивация")
plt.show()

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
sm.qqplot(df['Стрессоустойчивость'], line='45')
plt.title("Q-Q Plot Стрессоустойчивость")
plt.show()

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
sm.qqplot(df['Рейтинг в доте на данный момент'], line='45')
plt.title("Q-Q Plot Рейтинг")
plt.show()

# %%
import numpy as np
q3=np.percentile(df['Рейтинг в доте на данный момент'], 75)
q1=np.percentile(df['Рейтинг в доте на данный момент'], 25)
iqr=q3-q1
iqr_b=q1-1.5*iqr
iqr_t=q3+1.5*iqr
print(iqr_b, iqr_t)
# Out:
# -2325.0 6195.0

# %%
df[df['Рейтинг в доте на данный момент']> iqr_t].shape
# Out:
# (75, 36)

# %%
mean = df['Рейтинг в доте на данный момент'].mean()
std = df['Рейтинг в доте на данный момент'].std()
std_b=mean-3*std
std_t=mean+3*std
print(std_b, std_t)
# Out:
# -101859.77022941754 106787.96464402549

# %%
df[df['Рейтинг в доте на данный момент']> std_t].shape
# Out:
# (1, 36)

# %%
iqr_no=df[df['Рейтинг в доте на данный момент']< iqr_t]
std_no=df[df['Рейтинг в доте на данный момент']< std_t]

# %%
print(df['Рейтинг в доте на данный момент'].mean())
print(iqr_no['Рейтинг в доте на данный момент'].mean())
print(std_no['Рейтинг в доте на данный момент'].mean())
# Out:
# 2464.0972073039743
# 2002.7450155974502
# 2061.5813079092254

# %%
print(df['Рейтинг в доте на данный момент'].median())
print(iqr_no['Рейтинг в доте на данный момент'].median())
print(std_no['Рейтинг в доте на данный момент'].median())
# Out:
# 1810.0
# 1800.0
# 1810.0

# %%
import seaborn as sns
df_clean=df[df['Рейтинг в доте на данный момент'] <= 17000]

# %%
sm.qqplot(df_clean['Рейтинг в доте на данный момент'], line='45')
plt.title("Q-Q Plot Рейтинг")
# Out:
# Text(0.5, 1.0, 'Q-Q Plot Рейтинг')

# %%
from scipy.stats import kstest, norm
from scipy.stats import anderson
df_s = df_clean[['Рейтинг в доте на данный момент','Мотивация','Стрессоустойчивость']]
mean = df_s.mean()
std = df_s.std()
desc = df_s.describe().round(3)
desc.loc['mode'] = df_s.mode().iloc[0]
desc.loc['skewness'] = df_s.skew().round(3)
desc.loc['kurtosis'] = df_s.kurtosis().round(3)
desc.loc['ks_stat'] = df_s.apply(lambda x: kstest(x, norm.cdf, args=(mean[x.name], std[x.name])).statistic).round(3)
desc.loc['ks_p'] = df_s.apply(lambda x: kstest(x, norm.cdf, args=(mean[x.name], std[x.name])).pvalue).round(3)
desc.loc['anderson_stat'] = df_s.apply(lambda x: round(anderson(x).statistic, 3))
desc
# Out:
#                Рейтинг в доте на данный момент  Мотивация  Стрессоустойчивость
# count                                 7445.000   7445.000             7445.000
# mean                                  2053.109     15.020                8.482
# std                                   1494.820      3.707                2.748
# min                                      0.000      4.000                0.000
# 25%                                    870.000     13.000                7.000
# 50%                                   1810.000     16.000                9.000
# 75%                                   3000.000     18.000               11.000
# max                                  11900.000     20.000               12.000
# mode                                  2000.000     18.000                9.000
# skewness                                 0.898     -0.644               -0.913
# kurtosis                                 0.943     -0.242                0.463
# ks_stat                                  0.085      0.118                0.144
# ks_p                                     0.000      0.000                0.000
# anderson_stat                           94.259    109.822              163.387

# %%
import matplotlib.pyplot as plt
plt.hist(df_clean["Мотивация"])
# Out:
# (array([  90.,  182.,  196.,  515.,  392.,  962., 1286.,  787., 1567.,
#         1470.]),
#  array([ 4. ,  5.6,  7.2,  8.8, 10.4, 12. , 13.6, 15.2, 16.8, 18.4, 20. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_clean["Стрессоустойчивость"])
# Out:
# (array([ 161.,  130.,  193.,  270.,  321., 1101., 1029., 1149., 1149.,
#         1944.]),
#  array([ 0. ,  1.2,  2.4,  3.6,  4.8,  6. ,  7.2,  8.4,  9.6, 10.8, 12. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_clean["Рейтинг в доте на данный момент"])
# Out:
# (array([2.524e+03, 2.135e+03, 1.638e+03, 7.280e+02, 3.140e+02, 8.200e+01,
#         1.600e+01, 4.000e+00, 3.000e+00, 1.000e+00]),
#  array([    0.,  1190.,  2380.,  3570.,  4760.,  5950.,  7140.,  8330.,
#          9520., 10710., 11900.]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_clean["Рейтинг в доте на данный момент"], df_clean["Стрессоустойчивость"])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_clean["Рейтинг в доте на данный момент"], df_clean["Мотивация"])

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.distplot(df_clean['Рейтинг в доте на данный момент'])
# Out:
# C:\Users\Аннюта\AppData\Local\Temp\ipykernel_18556\400476201.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean['Рейтинг в доте на данный момент'])
# <Axes: xlabel='Рейтинг в доте на данный момент', ylabel='Density'>

# %%
sns.distplot(df_clean['Мотивация'])
# Out:
# C:\Users\Аннюта\AppData\Local\Temp\ipykernel_18556\1171417880.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean['Мотивация'])
# <Axes: xlabel='Мотивация', ylabel='Density'>

# %%
sns.distplot(df_clean['Стрессоустойчивость'])
# Out:
# C:\Users\Аннюта\AppData\Local\Temp\ipykernel_18556\1616123574.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean['Стрессоустойчивость'])
# <Axes: xlabel='Стрессоустойчивость', ylabel='Density'>

# %%
correlation=df_clean[['Мотивация', 'Стрессоустойчивость', 'Рейтинг в доте на данный момент']].corr(method='spearman')
correlation
# Out:
#                                  Мотивация  Стрессоустойчивость  \
# Мотивация                         1.000000             0.049658
# Стрессоустойчивость               0.049658             1.000000
# Рейтинг в доте на данный момент   0.132027             0.008843
#
#                                  Рейтинг в доте на данный момент
# Мотивация                                               0.132027
# Стрессоустойчивость                                     0.008843
# Рейтинг в доте на данный момент                         1.000000

# %%
from scipy.stats import spearmanr
import pandas as pd
cols = ['Мотивация', 'Стрессоустойчивость', 'Рейтинг в доте на данный момент']
data = df_clean[cols]

corr, p_values = spearmanr(data)
p_values_df = pd.DataFrame(p_values, columns=cols, index=cols )

p_values_df_rounded = p_values_df.round(4)
print(p_values_df_rounded)
# Out:
#                                  Мотивация  Стрессоустойчивость  \
# Мотивация                              0.0               0.0000
# Стрессоустойчивость                    0.0               0.0000
# Рейтинг в доте на данный момент        0.0               0.4455
#
#                                  Рейтинг в доте на данный момент
# Мотивация                                                 0.0000
# Стрессоустойчивость                                       0.4455
# Рейтинг в доте на данный момент                           0.0000

# %%
sns.heatmap(correlation, annot=True, vmax=1, vmin=-1)
# Out:
# <Axes: >

# %%
subset = df_clean[["Мотивация", "Рейтинг в доте на данный момент"]]
sns.pairplot(subset, diag_kind='kde')

# %%
subset = df_clean[['Стрессоустойчивость', "Рейтинг в доте на данный момент"]]
sns.pairplot(subset, diag_kind='kde')

# %%
from scipy import stats
X=df_clean['Рейтинг в доте на данный момент']
y=df_clean['Стрессоустойчивость']
res=stats.linregress(X,y)
res
# Out:
# LinregressResult(slope=-2.176664718079427e-05, intercept=8.526489157584612, rvalue=-0.0118414420820486, pvalue=0.30697208626058586, stderr=2.1305046315999176e-05, intercept_stderr=0.05410576116812777)

# %%
r_sq=res.rvalue**2
r_sq
# Out:
# 0.00014021975058251148

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(X,y, label='оригинальные данные')
plt.plot(X, res.intercept + res.slope*X, label='линия регрессии')
plt.legend()
plt.show()

# %%
A=df_clean['Рейтинг в доте на данный момент']
b=df_clean['Мотивация']
res=stats.linregress(A,b)
res
# Out:
# LinregressResult(slope=0.000335998687235107, intercept=14.32990297946657, rvalue=0.13547317953116694, pvalue=7.815786767858944e-32, stderr=2.848314384163041e-05, intercept_stderr=0.07233507757527768)

# %%
r_sq2=res.rvalue**2
r_sq2
# Out:
# 0.01835298237228379

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(A,b, label='оригинальные данные')
plt.plot(A, res.intercept + res.slope*A, label='линия регрессии')
plt.legend()
plt.show()
